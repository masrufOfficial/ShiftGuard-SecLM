# %% [markdown]
# # ShiftGuard-SecLM: Benchmark Evaluation Suite
#
# Runs multi-dimensional evaluation across all 11 security tasks:
# 1. Threat Reasoning (Precision / Recall / Macro-F1)
# 2. Security Requirement Extraction (Coverage / Precision)
# 3. CWE Classification (Top-1, Top-3, Multi-label F1)
# 4. OWASP Top 10 Taxonomy Mapping
# 5. Risk Calibration (Brier Score, Expected Calibration Error)
# 6. Vulnerability Reasoning
# 7. Security Strategy Assessment
# 8. Multi-Agent Capability Planning
# 9. Security Evidence Interpretation
# 10. Security Repair & Syntactic Validity
# 11. Re-Verification & Regression Checking
# 12. Held-Out Generalization (Unseen Archetypes)

# %%
# 1. Environment & Dependencies
# !pip install -q scikit-learn matplotlib seaborn pandas pydantic tokenizers safetensors pyyaml

# %%
# 2. Execute Benchmark Suite
# !python scripts/evaluate.py \
    --checkpoint /kaggle/working/checkpoints/pilot_110m/step_0000100 \
    --test-data datasets/manifests/test.jsonl \
    --tokenizer-path datasets/processed/tokenizer/tokenizer.json \
    --output-dir /kaggle/working/eval_results
